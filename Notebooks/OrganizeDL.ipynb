# %%
import os
import requests
import json
import pickle
import gc
import pandas as pd
import numpy as np
import scipy as sp
import seaborn as sn
from tqdm import tqdm, tqdm_notebook, tnrange, trange

# %%
tqdm_notebook().pandas()
# tqdm.pandas(tqdm_notebook)

# %%
# prefix = os.path.realpath("/mnt/f")
prefix = os.path.realpath("F:\\")

# %%
manifest = pd.read_csv(os.path.join(prefix, "GDC_Project/manifest/gdc_manifest.2017-12-13T20_11_55.178417.txt"), sep="\t")

# %%
manifest
# Out:
#                                          id  \
# 0      c5c4b4a3-3224-4a72-a883-c99c7747e47b
# 1      dd029237-d470-4b58-9cf0-11753fa60972
# 2      619c9069-53a8-4581-92a3-be1896fe7f66
# 3      30d8e7a6-675a-4999-a120-62add06bff3c
# 4      acd76d89-a4d7-47ea-a1c2-480a3d200634
# 5      c9b15d3d-7e1c-45f1-9119-cb5b9d8a4246
# 6      f3eaf986-c631-4fb4-b9e8-9cfaf5338210
# 7      4cea8ed2-8671-40b2-9310-225751043614
# 8      965aa608-bcda-4048-b65a-4836ae28e2a0
# 9      4fc747e8-c9a0-47f3-9273-4eb78ddbda9b
# 10     bccb90c4-cc9d-407d-85e5-1457fe02445a
# 11     af27346e-449f-4dde-a172-ca1ee3c10c82
# 12     8c576069-46a4-46cf-b072-6729712f6d5e
# 13     cf9ff5eb-cfc8-4004-ae0a-1e314135c2a2
# 14     765ae575-5ff3-4850-a280-bb547dc2da84
# 15     99814cd6-4d25-4cf6-88cb-71eed7b63322
# 16     527feea3-6c28-4d80-a34b-728f32cc5a34
# 17     20a875ef-d5a5-4793-9730-fea648a01ee5
# 18     98d79484-cd10-4759-bd2f-927e966f4b03
# 19     18dada78-89ff-4ca9-8886-58b58e47de1d
# ...

# %%
manifest_ids_in_table = 0
table_ids_in_manifest = 0

# %%
with open('../cleaned_tables/open_files.P', 'rb') as file:
    table = pickle.load(file)

# %%
table
# Out:
#        access            data_category data_format  \
# 1        open  Transcriptome Profiling         TXT
# 2        open  Transcriptome Profiling         TXT
# 7        open    Copy Number Variation         TXT
# 9        open          DNA Methylation         TXT
# 11       open                 Clinical     BCR XML
# 14       open  Transcriptome Profiling         TXT
# 15       open          DNA Methylation         TXT
# 16       open  Transcriptome Profiling         TXT
# 21       open          DNA Methylation         TXT
# 22       open                 Clinical     BCR XML
# 23       open    Copy Number Variation         TXT
# 24       open    Copy Number Variation         TXT
# 25       open    Copy Number Variation         TXT
# 26       open  Transcriptome Profiling         TXT
# 28       open  Transcriptome Profiling         TXT
# 29       open          DNA Methylation         TXT
# 30       open    Copy Number Variation         TXT
# ...
