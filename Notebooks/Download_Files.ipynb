# %%
import os
import requests
import json
import pickle
import gc
import pandas as pd
import numpy as np
import scipy as sp
import seaborn as sn
import hashlib
import io
import pathlib
from tqdm import tqdm, tqdm_notebook, tnrange, trange

# %%
tqdm_notebook().pandas()
# tqdm.pandas(tqdm_notebook)
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
desired_categories = ['Masked Copy Number Segment', 'Copy Number Segment', 'Methylation Beta Value', 'Clinical Supplement', 'Biospecimen Supplement', 'Masked Somatic Mutation']

# %%
def should_keep(rowdata):
    return rowdata['data_type'] in desired_categories

# %%
import urlpath
def generate_endpoints():
    host = urlpath.URL("https://api.gdc.cancer.gov")
    endpoints = dict()
    for point in ['files','cases','projects','annotations']:
        endpoints[point] = host / point
        endpoints["%s_mapping" % point] = host / point / "_mapping"
    endpoints['data'] = host / "data"
    endpoints['legacy_data'] = host / "legacy/data"
    endpoints['manifest'] = host / "manifest"
    return endpoints
endpoints = generate_endpoints()
endpoints
# Out:
# {'annotations': URL('https://api.gdc.cancer.gov/annotations'),
#  'annotations_mapping': URL('https://api.gdc.cancer.gov/annotations/_mapping'),
#  'cases': URL('https://api.gdc.cancer.gov/cases'),
#  'cases_mapping': URL('https://api.gdc.cancer.gov/cases/_mapping'),
#  'data': URL('https://api.gdc.cancer.gov/data'),
#  'files': URL('https://api.gdc.cancer.gov/files'),
#  'files_mapping': URL('https://api.gdc.cancer.gov/files/_mapping'),
#  'legacy_data': URL('https://api.gdc.cancer.gov/legacy/data'),
#  'manifest': URL('https://api.gdc.cancer.gov/manifest'),
#  'projects': URL('https://api.gdc.cancer.gov/projects'),
#  'projects_mapping': URL('https://api.gdc.cancer.gov/projects/_mapping')}

# %%
rootpath = pathlib.Path("..")
cleanpath = rootpath / "cleaned_tables"

# %%
with open(cleanpath / 'open_files.P', 'rb') as file:
    open_files = pickle.load(file)

# %%
open_files
# Out:
#        access            data_category data_format  \
# 1        open  Transcriptome Profiling         TXT
# 2        open  Transcriptome Profiling         TXT
# 7        open    Copy Number Variation         TXT
# 9        open          DNA Methylation         TXT
# 11       open                 Clinical     BCR XML
# 14       open  Transcriptome Profiling         TXT
# 15       open          DNA Methylation         TXT
# 16       open  Transcriptome Profiling         TXT
# 21       open          DNA Methylation         TXT
# 22       open                 Clinical     BCR XML
# 23       open    Copy Number Variation         TXT
# 24       open    Copy Number Variation         TXT
# 25       open    Copy Number Variation         TXT
# 26       open  Transcriptome Profiling         TXT
# 28       open  Transcriptome Profiling         TXT
# 29       open          DNA Methylation         TXT
# 30       open    Copy Number Variation         TXT
# 33       open    Copy Number Variation         TXT
# 39       open  Transcriptome Profiling         TXT
# 41       open    Copy Number Variation         TXT
# 43       open          DNA Methylation         TXT
# 45       open    Copy Number Variation         TXT
# 47       open    Copy Number Variation         TXT
# 48       open                 Clinical     BCR XML
# 51       open  Transcriptome Profiling         TXT
# 52       open  Transcriptome Profiling         TSV
# 53       open              Biospecimen     BCR XML
# 54       open  Transcriptome Profiling         TXT
# 57       open    Copy Number Variation         TXT
# 58       open  Transcriptome Profiling         TSV
# ...       ...                      ...         ...
# 303574   open                 Clinical     BCR XML
# 303575   open  Transcriptome Profiling         TXT
# 303576   open    Copy Number Variation         TXT
# 303577   open  Transcriptome Profiling         TXT
# 303578   open  Transcriptome Profiling         TSV
# 303581   open    Copy Number Variation         TXT
# 303583   open    Copy Number Variation         TXT
# 303585   open  Transcriptome Profiling         TXT
# 303586   open    Copy Number Variation         TXT
# 303588   open    Copy Number Variation         TXT
# 303590   open                 Clinical     BCR XML
# 303592   open                 Clinical     BCR XML
# 303595   open    Copy Number Variation         TXT
# 303596   open    Copy Number Variation         TXT
# 303598   open  Transcriptome Profiling         TSV
# 303600   open    Copy Number Variation         TXT
# 303605   open          DNA Methylation         TXT
# 303607   open              Biospecimen     BCR XML
# 303610   open    Copy Number Variation         TXT
# 303612   open              Biospecimen     BCR XML
# 303614   open              Biospecimen        XLSX
# 303981   open              Biospecimen        XLSX
# 304294   open                 Clinical        XLSX
# 304508   open              Biospecimen        XLSX
# 305551   open              Biospecimen        XLSX
# 305744   open              Biospecimen        XLSX
# 306173   open              Biospecimen        XLSX
# 307249   open              Biospecimen        XLSX
# 308314   open                 Clinical        XLSX
# 309021   open              Biospecimen        XLSX
#
#                                 data_type error_type experimental_strategy  \
# 1          Gene Expression Quantification        NaN               RNA-Seq
# 2          Gene Expression Quantification        NaN               RNA-Seq
# 7              Masked Copy Number Segment        NaN      Genotyping Array
# 9                  Methylation Beta Value        NaN     Methylation Array
# 11                    Clinical Supplement        NaN                   NaN
# 14         Gene Expression Quantification        NaN               RNA-Seq
# 15                 Methylation Beta Value        NaN     Methylation Array
# 16         Gene Expression Quantification        NaN               RNA-Seq
# 21                 Methylation Beta Value        NaN     Methylation Array
# 22                    Clinical Supplement        NaN                   NaN
# 23             Masked Copy Number Segment        NaN      Genotyping Array
# 24                    Copy Number Segment        NaN      Genotyping Array
# 25                    Copy Number Segment        NaN      Genotyping Array
# 26         Gene Expression Quantification        NaN               RNA-Seq
# 28         Gene Expression Quantification        NaN               RNA-Seq
# 29                 Methylation Beta Value        NaN     Methylation Array
# 30                    Copy Number Segment        NaN      Genotyping Array
# 33                    Copy Number Segment        NaN      Genotyping Array
# 39         Gene Expression Quantification        NaN               RNA-Seq
# 41             Masked Copy Number Segment        NaN      Genotyping Array
# 43                 Methylation Beta Value        NaN     Methylation Array
# 45                    Copy Number Segment        NaN      Genotyping Array
# 47             Masked Copy Number Segment        NaN      Genotyping Array
# 48                    Clinical Supplement        NaN                   NaN
# 51         Gene Expression Quantification        NaN               RNA-Seq
# 52        miRNA Expression Quantification       None             miRNA-Seq
# 53                 Biospecimen Supplement        NaN                   NaN
# 54         Gene Expression Quantification        NaN               RNA-Seq
# 57                    Copy Number Segment        NaN      Genotyping Array
# 58      Isoform Expression Quantification       None             miRNA-Seq
# ...                                   ...        ...                   ...
# 303574                Clinical Supplement        NaN                   NaN
# 303575     Gene Expression Quantification        NaN               RNA-Seq
# 303576                Copy Number Segment        NaN      Genotyping Array
# 303577     Gene Expression Quantification        NaN               RNA-Seq
# 58      submitted  011e4541beb2e16ce87ff1d3808518cd
# ...           ...                               ...
# 303574  submitted  82af8d7b66d4e14294af5cb186e7f2e7
# 303575  submitted  e791168ed8b66d3ac7110799817fa651
# 303576  submitted  23ada7deceec658283e75f8138aee6b8
# 303577  submitted  fe9fd96a5c07e748248a0408fc6b1524
# 303578  submitted  f32718b38f1136384947718e7524311e
# 303581  submitted  f6ed45a55c61125bbc8c66535eea737a
# 303583  submitted  2aa9c19668076c7538674a5e61ae70f6
# 303585  submitted  eea2be6ff359cb0aab5084802c31d8d7
# 303586  submitted  cd14611664484fa979a7d8cb0acbb630
# 303588  submitted  2a772286570f5b60733548e909780364
# 303590  submitted  4ce86ae497ef13ad213273c970994632
# 303592  submitted  25c868e13148856496cb1e556b0df9e7
# 303595  submitted  306eea905b7ee0ce55c9117581321b33
# 303596  submitted  4ae7e2082c43e53e8a992fb3e87729b6
# 303598  submitted  2c7b00fdb5e32a5883d9f9804323e31c
# 303600  submitted  7012f630051f9f617901640b40c151df
# 303605  submitted  e18de64db4125fc2feaece3065aab7a2
# 303607  submitted  417b969fa01b356f1ae01e8fe7340686
# 303610  submitted  9400cbf6fad915ae20f9ec6563a9528b
# 303612  submitted  22d56aef7b401ca9818a42f022d6d10e
# 303614  submitted  f430ae225eccfdce595637570984bee7
# 303981  submitted  cb7734928ae46768dc71455e82d81e9b
# 304294  submitted  a0c6700f9dab2725819167d17f331980
# 304508  submitted  e410c6df384a9271e0b5f6ea963463d0
# 305551  submitted  81c01ea864d2b344932d8ca398f39096
# 305744  submitted  90573ab92673dd5a8a687dec9de971d9
# 306173  submitted  38266082217a4f5675693ba29a79d1d4
# 307249  submitted  7259cfa5756f2796e87d70be83d60c2e
# 308314  submitted  e889a20eecba70e965462477f5845295
# 309021  submitted  e6f6e9a59d57f74bee8770267a2ee522
#
#                               platform      state  state_comment  \
# 1                                  NaN       live            NaN
# 2                                  NaN       live            NaN
# 7                   Affymetrix SNP 6.0       live            NaN
# 9        Illumina Human Methylation 27       live            NaN
# 11                                 NaN       live            NaN
# 14                                 NaN       live            NaN
# 15      Illumina Human Methylation 450       live            NaN
# 16                                 NaN       live            NaN
# 21       Illumina Human Methylation 27       live            NaN
# 22                                 NaN       live            NaN
# 23                  Affymetrix SNP 6.0       live            NaN
# 24                  Affymetrix SNP 6.0       live            NaN
# 25                  Affymetrix SNP 6.0       live            NaN
# 26                                 NaN       live            NaN
# 28                                 NaN       live            NaN
# 29       Illumina Human Methylation 27       live            NaN
# 30                  Affymetrix SNP 6.0       live            NaN
# 33                  Affymetrix SNP 6.0       live            NaN
# 39                                 NaN       live            NaN
# 41                  Affymetrix SNP 6.0       live            NaN
# 43      Illumina Human Methylation 450       live            NaN
# 45                  Affymetrix SNP 6.0       live            NaN
# 47                  Affymetrix SNP 6.0       live            NaN
# 48                                 NaN       live            NaN
# 51                                 NaN       live            NaN
# 52                                 NaN       live            NaN
# 53                                 NaN       live            NaN
# 54                                 NaN       live            NaN
# 57                  Affymetrix SNP 6.0       live            NaN
# 58                                 NaN       live            NaN
# ...                                ...        ...            ...
# 303574                             NaN       live            NaN
# 303575                             NaN       live            NaN
# 303576              Affymetrix SNP 6.0       live            NaN
# 303577                             NaN       live            NaN
# 303578                             NaN       live            NaN
# 303581              Affymetrix SNP 6.0       live            NaN
# 303583              Affymetrix SNP 6.0       live            NaN
# 303585                             NaN       live            NaN
# 303586              Affymetrix SNP 6.0       live            NaN
# 303588              Affymetrix SNP 6.0       live            NaN
# 303590                             NaN       live            NaN
# 303592                             NaN       live            NaN
# 303595              Affymetrix SNP 6.0       live            NaN
# 303596              Affymetrix SNP 6.0       live            NaN
# 303598                             NaN       live            NaN
# 303600              Affymetrix SNP 6.0       live            NaN
# 303605  Illumina Human Methylation 450       live            NaN
# 303607                             NaN       live            NaN
# 303610              Affymetrix SNP 6.0       live            NaN
# 303612                             NaN       live            NaN
# 303614                             NaN  submitted            NaN
# 303981                             NaN  submitted            NaN
# 304294                             NaN  submitted            NaN
# 304508                             NaN  submitted            NaN
# 305551                             NaN  submitted            NaN
# 305744                             NaN  submitted            NaN
# 306173                             NaN  submitted            NaN
# 307249                             NaN  submitted            NaN
# 308314                             NaN  submitted            NaN
# 309021                             NaN  submitted            NaN
#
#                                              submitter_id  \
# 1              81cab804-bfb1-44f0-ac2d-923e0766ac61_count
# 2               fc3748e5-79b4-4e5f-b0db-1d9cf4ed3cca_fpkm
# 7              49286f9e-4f03-4a25-af52-afdb4b571cee_nocnv
# 9         cde73b7c-0a50-4444-bb33-11e3debd3f79-beta-value
# 11                                                   None
# 14              17b38d44-cf29-495e-b145-68959926b3d9_fpkm
# 15        4a28321b-f56a-4fa2-8a88-26cbbcafbf85-beta-value
# 16              50bbf24f-b914-4e53-98ee-0cf22b2d9f01_fpkm
# 21        b8f77354-a4b5-49fa-a855-fa0e9c15657b-beta-value
# 22                                                   None
# 23             b1aa5acc-43db-465e-a586-132c7a915f53_nocnv
# 24            52d67774-440f-4e2c-81e7-cf6603af0055_allcnv
# 25            3d15e916-871e-4487-a692-ca9b31318176_allcnv
# 26             155f0f8e-9af5-452a-92ee-8b49d5df864e_count
# 28             49b5b772-6a7b-4aae-a9ed-8a95a0d9a28d_count
# 29        e87abe3e-9f0c-4242-883b-ee490bafa29a-beta-value
# 30            fbdf3f5c-744c-4a56-ae0f-a05869d33913_allcnv
# 33            f8a3c40d-bce0-477b-aeac-e2aa3edc3d31_allcnv
# 39              0ecefaf3-4a3f-4cf8-8c14-a46a54664a3e_fpkm
# 41             c3e816b5-6e6d-471c-a90e-32a37e72ae75_nocnv
# 43        ab40aa29-acb4-4584-bcfc-e4808214c10c-beta-value
# 45            826cd2ac-e2c1-4a8a-af2a-fc5cefd5f19d_allcnv
# 47             d95966e5-4386-48f9-981f-46bcf804da76_nocnv
# 48                                                   None
# 51            bf7d8fed-3bac-4a79-8c27-12785590bea5_uqfpkm
# 52         efdee0e5-dbf4-43a2-86d8-b1b53c9913fa_profiling
# 53                                                   None
# 54            3532257b-4596-490b-815d-447fb35dfbd9_uqfpkm
# 57            94739423-5bba-4360-9414-8e677c7ddc1f_allcnv
# 58      fc7efc31-11b0-43d6-8c4b-cef433c412ce_isoform_p...
# ...                                                   ...
# 303574                                               None
# 303575          9b4a8702-e00c-4a28-9e56-5a32bf3313af_fpkm
# 303576        95578b2e-76ed-4d23-acf3-0ae4cde0f996_allcnv
# 303577          dba2964e-2676-4aca-af36-5de4bd1036b9_fpkm
# 303578  3bdc5e08-f6d0-42af-a757-e8d0dd9241a7_isoform_p...
# 303581         36a838ea-c569-4521-abce-4c5685d2f541_nocnv
# 303583         31ec16d6-562c-474c-b0ef-48a0a985a894_nocnv
# 303585          73f7d513-46c8-4559-86cf-8b789c042e32_fpkm
# 303586         2214005d-a2f1-46b1-880f-079036e12c4b_nocnv
# 303588         9d86da8a-98ca-438b-81a8-888f1bfe5abd_nocnv
# 303590                                               None
# 303592                                               None
# 303595        f7200b92-7128-4ac8-a220-0b299a7de676_allcnv
# 303596        bc3b4455-db4b-4d02-99e1-fa2c8eccafa6_allcnv
# 303598     99e70b80-ddcd-4d77-8e09-7e9680163e59_profiling
# 303600         87297589-7bc0-4fb0-a5d9-1bab63495672_nocnv
# 303605    002dac8e-4dd0-4598-a98a-865325ac24f5-beta-value
# 303607                                               None
# 303610        670272e8-f524-4909-88a6-88d1ae3cfb22_allcnv
# 303612                                               None
# 303614                FM-AD_Biospecimen.Bronchus_And_Lung
# 303981     FM-AD_Biospecimen.Heart_Mediastinum_And_Pleura
# 304294                               FM-AD_Clinical.Ovary
# 304508  FM-AD_Biospecimen.Other_And_Unspecified_Urinar...
# 305551  FM-AD_Biospecimen.Peripheral_Nerves_And_Autono...
# 305744  FM-AD_Biospecimen.Other_Endocrine_Glands_And_R...
# 306173                           FM-AD_Biospecimen.Rectum
# 307249                           FM-AD_Biospecimen.Testis
# 308314                             FM-AD_Clinical.Bladder
# 309021              FM-AD_Biospecimen.Anus_And_Anal_Canal
#
#                           type program_name project_id  \
# 1              gene_expression         TCGA  TCGA-SARC
# 2              gene_expression         TCGA  TCGA-SARC
# 7          copy_number_segment         TCGA  TCGA-SARC
# 9       methylation_beta_value         TCGA    TCGA-OV
# 11         clinical_supplement         TCGA   TCGA-LGG
# 14             gene_expression         TCGA  TCGA-MESO
# 15      methylation_beta_value         TCGA  TCGA-THCA
# 16             gene_expression         TCGA  TCGA-SARC
# 21      methylation_beta_value         TCGA    TCGA-OV
# 22         clinical_supplement         TCGA  TCGA-THCA
# 23         copy_number_segment         TCGA  TCGA-THCA
# 24         copy_number_segment         TCGA    TCGA-OV
# 25         copy_number_segment         TCGA   TCGA-ACC
# 26             gene_expression         TCGA   TCGA-LGG
# 28             gene_expression         TCGA  TCGA-THCA
# 29      methylation_beta_value         TCGA    TCGA-OV
# 30         copy_number_segment         TCGA  TCGA-THCA
# 33         copy_number_segment         TCGA   TCGA-ACC
# 39             gene_expression         TCGA  TCGA-THCA
# 41         copy_number_segment         TCGA  TCGA-THCA
# 43      methylation_beta_value         TCGA   TCGA-LGG
# 45         copy_number_segment         TCGA   TCGA-LGG
# 47         copy_number_segment         TCGA   TCGA-LGG
# 48         clinical_supplement         TCGA    TCGA-OV
# 51             gene_expression         TCGA  TCGA-THCA
# 52            mirna_expression         TCGA  TCGA-THCA
# 53      biospecimen_supplement         TCGA    TCGA-OV
# 54             gene_expression         TCGA  TCGA-READ
# 57         copy_number_segment         TCGA   TCGA-LGG
# 58            mirna_expression         TCGA   TCGA-LGG
# ...                        ...          ...        ...
# 303574     clinical_supplement         TCGA  TCGA-BLCA
# 303575         gene_expression         TCGA  TCGA-BRCA
# 303576     copy_number_segment         TCGA  TCGA-LUAD
# 303577         gene_expression         TCGA  TCGA-KIRP
# 303578        mirna_expression         TCGA  TCGA-LUAD
# 303581     copy_number_segment         TCGA  TCGA-BRCA
# 303583     copy_number_segment         TCGA  TCGA-LUAD
# 303585         gene_expression         TCGA  TCGA-BRCA
# 303586     copy_number_segment         TCGA  TCGA-LUAD
# 303588     copy_number_segment         TCGA  TCGA-KIRP
# 303590     clinical_supplement         TCGA  TCGA-CESC
# 303592     clinical_supplement         TCGA  TCGA-BRCA
# 303595     copy_number_segment         TCGA  TCGA-PCPG
# 303596     copy_number_segment         TCGA  TCGA-BRCA
# 303598        mirna_expression       TARGET  TARGET-WT
# 303600     copy_number_segment         TCGA  TCGA-LUAD
# 303605  methylation_beta_value         TCGA  TCGA-BLCA
# 303607  biospecimen_supplement         TCGA  TCGA-BRCA
# 303610     copy_number_segment         TCGA  TCGA-BRCA
# 303612  biospecimen_supplement         TCGA  TCGA-LUAD
# 303614  biospecimen_supplement           FM      FM-AD
# 303981  biospecimen_supplement           FM      FM-AD
# 304294     clinical_supplement           FM      FM-AD
# 304508  biospecimen_supplement           FM      FM-AD
# 305551  biospecimen_supplement           FM      FM-AD
# 305744  biospecimen_supplement           FM      FM-AD
# 306173  biospecimen_supplement           FM      FM-AD
# 307249  biospecimen_supplement           FM      FM-AD
# 308314     clinical_supplement           FM      FM-AD
# 309021  biospecimen_supplement           FM      FM-AD
#
#                                                   case_id  n_cases
# 1                  [8f3f6f7c-4b50-467e-a6e8-d836735913f6]      1.0
# 2                  [1cbcfbb0-fcad-4ccd-8e83-120faa3e0df3]      1.0
# 7                  [e786de34-4c21-460f-89ab-008de4347049]      1.0
# 9                  [6746533a-8d0b-4ebc-87ec-49c8738121a8]      1.0
# 11                 [da13446a-c4dc-4d02-80c8-410273925ac4]      1.0
# 14                 [c5d4d4b4-2c9e-4865-8860-68327356d461]      1.0
# 15                 [861f94ce-45ff-4588-addb-e1ea48878c2e]      1.0
# 16                 [2905cbd1-719b-46d9-b8af-8fe4927bc473]      1.0
# 21                 [3e8a51bf-7e1f-4eab-af83-3c60d04db1bf]      1.0
# 22                 [8ed1b900-a8a8-4164-b96b-f060f15d7075]      1.0
# 23                 [4fa53eb7-1fdb-4fe5-b5ad-f3d8069b3eb8]      1.0
# 24                 [46395c3d-5e51-477f-946e-e58b87cc7baa]      1.0
# 25                 [5f3e2974-f1df-47a2-8a8a-29bb525eeef6]      1.0
# 304294  [8cede5dc-2982-49e6-a7a6-73c928039a14, 5d62407...    937.0
# 304508  [5805b09e-3776-47b5-9ba3-d8f435464ec9, c785bbf...     14.0
# 305551  [91077609-b6e1-4a3d-b9b6-11f14367eba7, 9c43388...     14.0
# 305744  [3c595273-c1c2-4eef-b784-4ae44db018db, acb5605...      6.0
# 306173  [3f9dd36e-d8bd-42db-89bf-b98efcd897df, cb099c9...    279.0
# 307249  [ca2a42ac-094b-4911-a9f1-27602ceb7553, 3149216...     22.0
# 308314  [5ca60ab5-4fd1-4cad-a763-326c52f638f6, 027c4e0...    344.0
# 309021  [6dd040b4-4506-4dfd-9e50-981a4bb1f72b, 1bb9652...     70.0
#
# [137523 rows x 20 columns]

# %%
wanted_files = open_files.where(open_files.progress_apply(should_keep, axis='columns')).dropna(how='all')
# Out:
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))

# %%
wanted_files.shape
# Out:
# (79825, 20)

# %%
params = dict()
# params['pretty'] = 'True'

# %%
def raise_oserror(oserror):
    raise oserror

for root, dirs, files in os.walk("../GDC_Download", followlinks=True, onerror=raise_oserror):
    dirlist= pd.Series(dirs)
    break

# %%
files
# Out:
# []

# %%
dirlist = dirlist.where(dirlist != "GDC_Initial_DL").dropna()

# %%
dirlist
# Out:
# 0        00005051-36c7-4850-9e2c-243be54077ea
# 1        00006c36-08ae-4f93-a580-1b798d153d7c
# 2        0000c40e-9d45-4446-9dd9-a4676224d0ce
# 3        00015d5e-3aad-4f2a-9136-e0a40eacd0b6
# 4        0004067c-f0fd-4010-95b0-0310c076acb0
# 5        0004c5df-ba54-4ce5-b76a-7209d4a10db0
# 6        00052bb8-ca7a-45cd-b625-8f4e2f906448
# 7        000726ad-c183-4cdb-aea9-8a6af84be527
# 8        000917ce-772d-4a57-8be3-57d73c18cf2a
# 9        000977fc-eb56-4201-b247-0514cb1efae9
# 10       000ad857-288a-481f-9954-10fe0b4324a9
# 11       000bf387-328d-4119-b92b-d1715106f0b4
# 12       000c68e6-478f-4754-b753-9270b7ad7c61
# 13       000d2816-b40c-4323-ae07-faf50b43fdfb
# 14       000da838-2c48-4854-bcae-534e1aac2193
# 15       000f00b5-573a-4520-b3de-ba81e9671a71
# 16       00135244-3e40-44d6-8cf5-bc8e4a8c4ae1
# 17       00135bd8-170a-4976-b387-0e2d477d97d2
# 18       0014ba68-0c36-4df0-ad38-b668780142c2
# 19       00161f54-39bc-44f7-8af4-7d0e7970bed6
# 20       00164357-a731-40dd-a717-6f468d0d3498
# 21       00166964-4137-4b93-b61d-f9182e90ed8c
# 22       00166d1b-3270-4656-a7e7-2b053278b980
# 23       00175fb5-0ba1-45e7-b949-0cb38aa190a3
# 24       0018c6c4-60b0-47ae-afe2-6b045349fdd9
# 25       0018ef59-1ccc-4951-b3c0-c14f6bd41c2b
# 26       0019cb17-18de-4546-86c3-8c906273705f
# 27       001a88a4-c79c-497a-a72b-fd066354cedc
# 28       001bc81c-3b44-418d-9561-c9a79b69fa56
# 29       001c4518-c2a7-4fe8-a307-ffc5392cf7d6
#                          ...
# 79795    ffec9c37-a7bb-495f-9b7d-3fd0af6275f5
# 79796    ffed3230-4cdc-40bc-8bc4-9a738adb6d23
# 79797    ffed7cc9-10dd-46bf-afd7-77d63f0f930d
# 79798    ffeecedd-6d09-44fb-a5e4-f6817b7f7079
# 79799    fff112eb-4c88-4d2b-9f96-ca63ad095af1
# 79800    fff18bdd-183c-47ab-9434-44d6d0769e02
# 79801    fff22d03-aea4-4c8c-b00a-a67b2d36a070
# 79802    fff28755-c5bd-4c9c-9475-6c0846717d3e
# 79803    fff377fe-c4f9-445d-b523-a9d10fe9d089
# 79804    fff479ed-5f4f-4cee-b50c-88ad75c0297c
# 79805    fff5370e-8a9f-4170-b7e2-d175b55552d2
# 79806    fff61cb7-e48f-490b-82ca-398b8a4f1617
# 79807    fff6ac4f-a1cc-49ae-a75f-52d352590ec9
# 79808    fff71c0b-9f37-446d-9833-52a2c407e783
# 79809    fff71c54-4235-4766-b470-bfc0feab8e3b
# 79810    fff741ba-10f7-428a-b170-3372d2e8fe4f
# 79811    fff8edd0-a091-4e08-adc9-843946c8681a
# 79812    fff8ff71-7c4d-4f25-a611-7843b8b84b45
# 79813    fff9c188-67cb-43e4-85d4-9c0db5ba1cb1
# 79814    fffa1803-c7fa-4191-90d5-ad8f856aded9
# 79815    fffa64b6-4001-4792-9943-eef810912fd2
# 79816    fffc150b-f897-4e8e-b494-e0ae6d5d5a69
# 79817    fffc75da-70cd-45d1-bba9-1b13c11af96f
# 79818    fffd0830-81bc-4bae-ad1b-b8aa30375df6
# 79819    fffd4f84-3984-4995-924e-9fc60c9f93b9
# 79820    fffd522a-a225-4f5d-957b-ad621b182510
# 79821    fffda7cc-5908-48cd-a574-fbad99e5d5f4
# 79822    fffe72b2-6f7b-474e-b595-671445b5c4ec
# 79823    ffff03a4-a8a4-449e-9202-bc9b64cfb2e4
# 79824    ffffa9e1-5df6-4c3d-bba3-bc00c89220ed
# Length: 79825, dtype: object

# %%
wanted_files_uuid_set = set(wanted_files['file_id'].values)
download_uuid_set = set(dirlist.values)

# %%
keep_these = wanted_files_uuid_set & download_uuid_set
remove_these = download_uuid_set - wanted_files_uuid_set
download_these = wanted_files_uuid_set - download_uuid_set

# %%
def to_df(setobj, other_df):
    df = pd.DataFrame()
    df['file_id'] = list(setobj)
    return df.merge(other_df, on='file_id')
keep_files_df = to_df(keep_these, open_files)
dl_files_df = to_df(download_these, open_files)

# %%
print("\n".join(dl_files_df.data_type.unique()))

# %%
print("\n".join(wanted_files.data_type.unique()))
# Out:
# Masked Copy Number Segment
# Methylation Beta Value
# Clinical Supplement
# Copy Number Segment
# Biospecimen Supplement
# Masked Somatic Mutation

# %%
len(keep_these)
# Out:
# 79825

# %%
len(remove_these)
# Out:
# 0

# %%
len(download_these)
# Out:
# 0

# %%
len(download_uuid_set)
# Out:
# 79825

# %%
len(wanted_files_uuid_set)
# Out:
# 79825

# %%
print("\n".join(open_files.data_type.unique()))
# Out:
# Gene Expression Quantification
# Masked Copy Number Segment
# Methylation Beta Value
# Clinical Supplement
# Copy Number Segment
# miRNA Expression Quantification
# Biospecimen Supplement
# Isoform Expression Quantification
# Masked Somatic Mutation

# %%
open_files.where(open_files.data_type == "Clinical Supplement").program_name.dropna().unique()
# Out:
# array(['TCGA', 'TARGET', 'FM'], dtype=object)

# %%
manifest = pd.read_csv("../manifest/gdc_manifest.2017-12-13T20_11_55.178417.txt", sep="\t")

# %%
manifest.rename(columns={'id':'file_id'}, inplace=True)

# %%
rm_files_df = to_df(remove_these, manifest)

# %%
keep_files_df
# Out:
#                                     file_id access          data_category  \
# 0      12a87d54-7d1f-4e42-bf36-c1b3936f67bc   open        DNA Methylation
# 1      5ae85640-5f74-4cfe-9205-08b6c07e8f7a   open  Copy Number Variation
# 2      abd4a6da-0fd8-4f45-9e99-5f9c901e4b37   open               Clinical
# 3      5349b90d-5979-478b-b464-7bdded5cc4f6   open  Copy Number Variation
# 4      87a67342-5b9c-4528-93cc-aca8565e47a4   open               Clinical
# 5      978eff68-5139-4871-bf64-23dd38350c8a   open            Biospecimen
# 6      9f588f06-5fc7-4b0a-a927-9dfdd472b51b   open  Copy Number Variation
# 7      ea66c40d-3af4-413c-ba8a-2d117c7428f5   open  Copy Number Variation
# 8      d27c111f-1b28-4c32-ad29-e0783388e4b9   open  Copy Number Variation
# 9      d455aec1-86b5-4c18-ae99-95ad16a5352a   open  Copy Number Variation
# 10     e317065a-f17c-48d5-ac94-2d21e74ddca4   open        DNA Methylation
# 11     29f7b487-0af9-4e83-90ed-d54eb66e5e79   open  Copy Number Variation
# 12     5ca5dc52-f857-46f3-b61b-a086866c7699   open  Copy Number Variation
# 13     349cc87d-acda-46c5-a5b3-28efb7a7aa48   open        DNA Methylation
# 14     08e4738a-e192-47f0-8231-f5f6faac7c06   open  Copy Number Variation
# 15     c7705435-df1d-4a0d-9e7d-ad8ff94eef14   open  Copy Number Variation
# 16     69d53b48-cac7-4acf-839e-993ea65d752c   open  Copy Number Variation
# 17     63ecc149-5390-4133-b024-927d187cfaed   open  Copy Number Variation
# 18     a50f4b7a-70ac-42d6-94a2-1e4c68583517   open        DNA Methylation
# 19     146b6977-3a1f-48fb-8e58-f4c9ee8054cd   open            Biospecimen
# 20     98abdb27-c161-42c2-bb1f-ba84e8dd4e75   open  Copy Number Variation
# 21     13bcebb7-ff91-4109-8b31-d59a5f2beb36   open  Copy Number Variation
# 22     67d3b83f-b314-49a1-be97-3c8347f27665   open  Copy Number Variation
# 23     20d34bdd-2d2b-4c59-946e-fded0595312c   open  Copy Number Variation
# 24     1f74bb9b-aa75-43f1-a312-ce826b86528f   open  Copy Number Variation
# 25     7d6be126-e215-411a-9633-cd92a8b7de16   open  Copy Number Variation
# 26     e537fabf-17d0-4a9e-a1d8-05438232a635   open            Biospecimen
# 27     2ddc036c-b5ed-4619-ac79-477878967844   open        DNA Methylation
# 28     fbbdcfa2-416f-4be4-9232-acd10a2a9fd3   open  Copy Number Variation
# 29     27d5fe99-adc4-4d47-83ee-c15d78adfa8b   open  Copy Number Variation
# ...                                     ...    ...                    ...
# 79795  92efc386-c6cf-43c8-b55b-eac41d8feb78   open  Copy Number Variation
# 79796  215027ad-568d-43ae-82c6-8876475e9eae   open            Biospecimen
# 79797  435ec6a9-f8d6-4910-8909-2e99f5c7b689   open  Copy Number Variation
# 79798  29ebacf5-d1e2-4956-b87f-d5e4a14b25c6   open        DNA Methylation
# 79799  c8974553-b6f2-40f0-af06-ca1b2695330a   open  Copy Number Variation
# 79800  0c5075a0-9741-47c2-89c8-4f98e4d2782d   open        DNA Methylation
# 79801  987a7dfd-2e85-47be-ad27-454c5fdc7a36   open            Biospecimen
# 79802  c649d9df-de55-4366-b163-1f2059333c67   open  Copy Number Variation
# 79803  d8a69383-246b-484e-9c49-c31da352a945   open  Copy Number Variation
# 79804  f80d2fcb-4354-425d-9345-e807d1e3a869   open  Copy Number Variation
# 79805  fd0e3c10-0e6d-4d0c-85dd-dbcfcf1ad441   open               Clinical
# 79806  bc70a2be-db4e-4a40-9284-4ce21a3d6f06   open  Copy Number Variation
# 79807  e57f6825-4d0d-44c0-bf48-ae12f6f56e8e   open  Copy Number Variation
# 79808  16b32aa8-2b2f-4294-9f05-6c63a3583780   open            Biospecimen
# 79809  05897e12-4812-48c5-8604-a8b38c08360c   open            Biospecimen
# 79810  21cdbd62-d71e-4e7d-b720-d9ddb8249baf   open  Copy Number Variation
# 79811  71fec95d-90a7-424a-a058-bcaaa50ebfc3   open               Clinical
# 79812  bb60d47a-7246-41dd-be5f-0389d2cfa68e   open        DNA Methylation
# 79813  15811bc6-6d29-4d92-96d8-efdc6ec97446   open  Copy Number Variation
# 79814  5dc8f76a-19c0-4c7c-baa7-720859c13059   open               Clinical
# 79815  788378fe-e42f-455c-a548-1af299e45c45   open  Copy Number Variation
# 79816  8b2e08c8-f585-4801-a7b7-27ddd2aeee8b   open  Copy Number Variation
# 79817  cd6cb058-6606-4360-b792-3f663b1d92ee   open  Copy Number Variation
# 79818  f8f766ba-b9ea-4067-adf9-1e3a35b5da02   open               Clinical
# 79819  2e3e14f3-3746-42c9-8c8d-2067c3fab17b   open  Copy Number Variation
# 79820  ba6ad12b-c2a3-45e4-8347-50533a149ae1   open  Copy Number Variation
# 79821  ece4fe1e-5f3a-47f7-bc09-082e6d54f139   open            Biospecimen
# 79822  988ca913-0ce2-471d-b193-2d35bf2bbc09   open  Copy Number Variation
# 79823  32ce2101-bbe6-44f2-8a6f-60dc128ba420   open  Copy Number Variation
# 79824  d21ba9bf-c6a6-4fa2-99a4-c80bfb7d2985   open            Biospecimen
#
#       data_format                   data_type error_type  \
# 0             TXT      Methylation Beta Value        NaN
# 1             TXT  Masked Copy Number Segment        NaN
# 2         BCR XML         Clinical Supplement        NaN
# 3             TXT  Masked Copy Number Segment        NaN
# 4         BCR XML         Clinical Supplement        NaN
# 5         BCR XML      Biospecimen Supplement        NaN
# 6             TXT  Masked Copy Number Segment        NaN
# 7             TXT         Copy Number Segment        NaN
# 8             TXT         Copy Number Segment        NaN
# 9             TXT  Masked Copy Number Segment        NaN
# 10            TXT      Methylation Beta Value        NaN
# 11            TXT         Copy Number Segment        NaN
# 12            TXT  Masked Copy Number Segment        NaN
# 13            TXT      Methylation Beta Value        NaN
# 14            TXT         Copy Number Segment        NaN
# 15            TXT  Masked Copy Number Segment        NaN
# 16            TXT         Copy Number Segment        NaN
# 17            TXT         Copy Number Segment        NaN
# 18            TXT      Methylation Beta Value        NaN
# 19        BCR XML      Biospecimen Supplement        NaN
# 20            TXT         Copy Number Segment        NaN
# 21            TXT         Copy Number Segment        NaN
# 22            TXT         Copy Number Segment        NaN
# 23            TXT  Masked Copy Number Segment        NaN
# 24            TXT  Masked Copy Number Segment        NaN
# 25            TXT         Copy Number Segment        NaN
# 26        BCR XML      Biospecimen Supplement        NaN
# 27            TXT      Methylation Beta Value        NaN
# 28            TXT  Masked Copy Number Segment        NaN
# 29            TXT         Copy Number Segment        NaN
# ...           ...                         ...        ...
# 79795         TXT  Masked Copy Number Segment        NaN
# 79796     BCR XML      Biospecimen Supplement        NaN
# 79797         TXT  Masked Copy Number Segment        NaN
# 79798         TXT      Methylation Beta Value        NaN
# 79799         TXT  Masked Copy Number Segment        NaN
# 79800         TXT      Methylation Beta Value        NaN
# 79801     BCR XML      Biospecimen Supplement        NaN
# 79802         TXT  Masked Copy Number Segment        NaN
# 79803         TXT         Copy Number Segment        NaN
# 79804         TXT  Masked Copy Number Segment        NaN
# 79805     BCR XML         Clinical Supplement        NaN
# 79806         TXT  Masked Copy Number Segment        NaN
# 79807         TXT  Masked Copy Number Segment        NaN
# 79808     BCR XML      Biospecimen Supplement        NaN
# 79809     BCR XML      Biospecimen Supplement        NaN
# 79810         TXT  Masked Copy Number Segment        NaN
# 79811     BCR XML         Clinical Supplement        NaN
# 79812         TXT      Methylation Beta Value        NaN
# 79813         TXT  Masked Copy Number Segment        NaN
# 79814     BCR XML         Clinical Supplement        NaN
# 79815         TXT         Copy Number Segment        NaN
# 79816         TXT  Masked Copy Number Segment        NaN
# 79817         TXT         Copy Number Segment        NaN
# 79818     BCR XML         Clinical Supplement        NaN
# 79819         TXT         Copy Number Segment        NaN
# 79820         TXT  Masked Copy Number Segment        NaN
# 79821     BCR XML      Biospecimen Supplement        NaN
# 79822         TXT  Masked Copy Number Segment        NaN
# 79823         TXT         Copy Number Segment        NaN
# 79824     BCR XML      Biospecimen Supplement        NaN
#
#       experimental_strategy  \
# 0         Methylation Array
# 1          Genotyping Array
# 2                       NaN
# 3          Genotyping Array
# 4                       NaN
# 5                       NaN
# 6          Genotyping Array
# 7          Genotyping Array
# 8          Genotyping Array
# 9          Genotyping Array
# 10        Methylation Array
# 11         Genotyping Array
# 12         Genotyping Array
# 13        Methylation Array
# 14         Genotyping Array
# 15         Genotyping Array
# 16         Genotyping Array
# 17         Genotyping Array
# 18        Methylation Array
# 19                      NaN
# 20         Genotyping Array
# 21         Genotyping Array
# 22         Genotyping Array
# 23         Genotyping Array
# 24         Genotyping Array
# 25         Genotyping Array
# 26                      NaN
# 27        Methylation Array
# 28         Genotyping Array
# 29         Genotyping Array
# ...                     ...
# 79795      Genotyping Array
# 79796                   NaN
# 79797      Genotyping Array
# 79798     Methylation Array
# 79799      Genotyping Array
# 79800     Methylation Array
# 79801                   NaN
# 79802      Genotyping Array
# 79803      Genotyping Array
# 79804      Genotyping Array
# 79805                   NaN
# 79806      Genotyping Array
# 79807      Genotyping Array
# 79808                   NaN
# 79809                   NaN
# 79810      Genotyping Array
# 79811                   NaN
# 79812     Methylation Array
# 79813      Genotyping Array
# 79814                   NaN
# 79815      Genotyping Array
# 79816      Genotyping Array
# 79817      Genotyping Array
# 79818                   NaN
# 79819      Genotyping Array
# 79820      Genotyping Array
# 79821                   NaN
# 79822      Genotyping Array
# 79823      Genotyping Array
# 79824                   NaN
#
#                                                file_name    file_size  \
# 0      jhu-usc.edu_KICH.HumanMethylation450.1.lvl-3.T...  141283346.0
# 1      RUNIC_p_2TCGA235_237_250_242_mN_GenomeWideSNP_...       3112.0
# 2      nationwidechildrens.org_clinical.TCGA-KL-8344.xml      31021.0
# 3      BINGE_p_TCGAb_366_P01_NSP_GenomeWideSNP_6_B05_...       7411.0
# 4      nationwidechildrens.org_clinical.TCGA-DH-A7UT.xml      49661.0
# 5      nationwidechildrens.org_biospecimen.TCGA-HC-A4...      52303.0
# 6      PHYLE_p_TCGA_189_193_Rec_SNP_N_GenomeWideSNP_6...      14914.0
# 7      SHUNS_p_TCGAb_388_389_NSP_GenomeWideSNP_6_A08_...      51382.0
# 8      PEAKY_p_TCGA_b164_SNP_N_GenomeWideSNP_6_D09_86...      30484.0
# 9      HERMS_p_TCGAb_391_NSP_GenomeWideSNP_6_D05_1473...      30318.0
# 10     jhu-usc.edu_LUAD.HumanMethylation450.14.lvl-3....  141239599.0
# 11     GLIAS_p_TCGA_204_205_206_207_N_GenomeWideSNP_6...      33745.0
# 12     CULLS_p_TCGAb_432_NSP_GenomeWideSNP_6_D06_1537...      11419.0
# 13     jhu-usc.edu_STAD.HumanMethylation450.4.lvl-3.T...  141272477.0
# 14     BLAIN_p_TCGA_282_304_b2_N_GenomeWideSNP_6_E07_...      55968.0
# 15     WANED_p_TCGAb_113_420_NSP_GenomeWideSNP_6_C05_...       5990.0
# 16     CARRS_p_TCGASNP_b92_N_GenomeWideSNP_6_B08_7356...      32858.0
# 17     DEVEL_p_TCGAb3_73_74_75_76_NSP_GenomeWideSNP_6...      71783.0
# 18     jhu-usc.edu_SARC.HumanMethylation450.1.lvl-3.T...  141299002.0
# 19     nationwidechildrens.org_biospecimen.TCGA-CG-43...      92150.0
# 20     INCUS_p_TCGAb3_43_44_45_46_STY_GenomeWideSNP_6...      45150.0
# 21           TCGA_AB_2883_03A_01D_0756_21.grch38.seg.txt      56835.0
# 22     DADOS_p_TCGAb3_85_86_87_88_NSP_GenomeWideSNP_6...      40226.0
# 23     CULLS_p_TCGAb_432_NSP_GenomeWideSNP_6_F09_1537...       7936.0
# 24     THING_p_TCGA_B19_SNP_N_GenomeWideSNP_6_A03_495...      51976.0
# 25     MATZO_p_TCGAb40_SNP_1N_GenomeWideSNP_6_E01_667...      83477.0
# 79813  submitted  4431fe8a0985ff5afc2894c4511ec3de
# 79814  submitted  a44f23b32a1ea9298219cdfee2940163
# 79815  submitted  09ca76846467e16c92f47340016441e3
# 79816  submitted  796ba8885d557bb976a73904ec7edd30
# 79817  submitted  c2b07c6bf6952b9912d9885b91745b96
# 79818  submitted  f642a53f5aa231733bdc5639c61b6e98
# 79819  submitted  46f94652d37f036242cceafadde4c845
# 79820  submitted  9aee4e6b88cd325690833b06638c2a33
# 79821  submitted  d171f1fd87c2a8ef1f0963a356ed0686
# 79822  submitted  aa953583b8268828a0142fcbd6ee301f
# 79823  submitted  afca31589fa86b3189ed1c43cb300db8
# 79824  submitted  5b55b9023b4912cdf7615a517146da48
#
#                              platform state  state_comment  \
# 0      Illumina Human Methylation 450  live            NaN
# 1                  Affymetrix SNP 6.0  live            NaN
# 2                                 NaN  live            NaN
# 3                  Affymetrix SNP 6.0  live            NaN
# 4                                 NaN  live            NaN
# 5                                 NaN  live            NaN
# 6                  Affymetrix SNP 6.0  live            NaN
# 7                  Affymetrix SNP 6.0  live            NaN
# 8                  Affymetrix SNP 6.0  live            NaN
# 9                  Affymetrix SNP 6.0  live            NaN
# 10     Illumina Human Methylation 450  live            NaN
# 11                 Affymetrix SNP 6.0  live            NaN
# 12                 Affymetrix SNP 6.0  live            NaN
# 13     Illumina Human Methylation 450  live            NaN
# 14                 Affymetrix SNP 6.0  live            NaN
# 15                 Affymetrix SNP 6.0  live            NaN
# 16                 Affymetrix SNP 6.0  live            NaN
# 17                 Affymetrix SNP 6.0  live            NaN
# 18     Illumina Human Methylation 450  live            NaN
# 19                                NaN  live            NaN
# 20                 Affymetrix SNP 6.0  live            NaN
# 21                 Affymetrix SNP 6.0  live            NaN
# 22                 Affymetrix SNP 6.0  live            NaN
# 23                 Affymetrix SNP 6.0  live            NaN
# 24                 Affymetrix SNP 6.0  live            NaN
# 25                 Affymetrix SNP 6.0  live            NaN
# 26                                NaN  live            NaN
# 27     Illumina Human Methylation 450  live            NaN
# 28                 Affymetrix SNP 6.0  live            NaN
# 29                 Affymetrix SNP 6.0  live            NaN
# ...                               ...   ...            ...
# 79795              Affymetrix SNP 6.0  live            NaN
# 79796                             NaN  live            NaN
# 79797              Affymetrix SNP 6.0  live            NaN
# 79798  Illumina Human Methylation 450  live            NaN
# 79799              Affymetrix SNP 6.0  live            NaN
# 79800  Illumina Human Methylation 450  live            NaN
# 79801                             NaN  live            NaN
# 79802              Affymetrix SNP 6.0  live            NaN
# 79803              Affymetrix SNP 6.0  live            NaN
# 79804              Affymetrix SNP 6.0  live            NaN
# 79805                             NaN  live            NaN
# 79806              Affymetrix SNP 6.0  live            NaN
# 79807              Affymetrix SNP 6.0  live            NaN
# 79808                             NaN  live            NaN
# 79809                             NaN  live            NaN
# 79810              Affymetrix SNP 6.0  live            NaN
# 79811                             NaN  live            NaN
# 79812  Illumina Human Methylation 450  live            NaN
# 79813              Affymetrix SNP 6.0  live            NaN
# 79814                             NaN  live            NaN
# 79815              Affymetrix SNP 6.0  live            NaN
# 79808                                             None
# 79809                                             None
# 79810       c8ffb064-5b99-44db-80f8-d2415e051c82_nocnv
# 79811                                             None
# 79812  39706279-0e85-4484-b5df-810f509b98dd-beta-value
# 79813       ab627b90-c455-4592-b669-1d26a1d396d0_nocnv
# 79814                                             None
# 79815      51f3419f-9e17-4a61-a71f-46511531a057_allcnv
# 79816       1ee39251-5217-43a6-b04c-2179b6cda5d3_nocnv
# 79817      3b03ed42-38e2-4a3e-9c07-4d29299af08d_allcnv
# 79818                                             None
# 79819      4d69c0bd-73c2-4d78-b713-28939f536dea_allcnv
# 79820       dce044e0-4e1c-4279-9e43-0d0613ae76a4_nocnv
# 79821                                             None
# 79822       6f938f6f-e49b-4581-9bca-349ff7385455_nocnv
# 79823      0df54e55-3a4e-4af9-9c65-3fa50db9f5cd_allcnv
# 79824                                             None
#
#                          type program_name project_id  \
# 0      methylation_beta_value         TCGA  TCGA-KICH
# 1         copy_number_segment         TCGA  TCGA-THCA
# 2         clinical_supplement         TCGA  TCGA-KICH
# 3         copy_number_segment         TCGA  TCGA-PCPG
# 4         clinical_supplement         TCGA   TCGA-LGG
# 5      biospecimen_supplement         TCGA  TCGA-PRAD
# 6         copy_number_segment         TCGA   TCGA-LGG
# 7         copy_number_segment         TCGA  TCGA-SKCM
# 8         copy_number_segment         TCGA  TCGA-HNSC
# 9         copy_number_segment         TCGA  TCGA-BLCA
# 10     methylation_beta_value         TCGA  TCGA-LUAD
# 11        copy_number_segment         TCGA  TCGA-THCA
# 12        copy_number_segment         TCGA  TCGA-KIRP
# 13     methylation_beta_value         TCGA  TCGA-STAD
# 14        copy_number_segment         TCGA   TCGA-ACC
# 15        copy_number_segment         TCGA  TCGA-CESC
# 16        copy_number_segment         TCGA  TCGA-UCEC
# 17        copy_number_segment         TCGA  TCGA-BRCA
# 18     methylation_beta_value         TCGA  TCGA-SARC
# 19     biospecimen_supplement         TCGA  TCGA-STAD
# 20        copy_number_segment         TCGA  TCGA-KIRP
# 21        copy_number_segment         TCGA  TCGA-LAML
# 22        copy_number_segment         TCGA  TCGA-COAD
# 23        copy_number_segment         TCGA  TCGA-KIRP
# 24        copy_number_segment         TCGA    TCGA-OV
# 25        copy_number_segment         TCGA    TCGA-OV
# 26     biospecimen_supplement         TCGA  TCGA-LUSC
# 27     methylation_beta_value         TCGA  TCGA-CESC
# 28        copy_number_segment         TCGA  TCGA-ESCA
# 29        copy_number_segment         TCGA  TCGA-KIRC
# ...                       ...          ...        ...
# 79795     copy_number_segment         TCGA  TCGA-HNSC
# 79796  biospecimen_supplement         TCGA  TCGA-LUAD
# 79797     copy_number_segment         TCGA  TCGA-LIHC
# 79798  methylation_beta_value         TCGA  TCGA-LAML
# 79799     copy_number_segment         TCGA  TCGA-LIHC
# 79800  methylation_beta_value         TCGA  TCGA-HNSC
# 79801  biospecimen_supplement         TCGA  TCGA-KICH
# 79802     copy_number_segment         TCGA  TCGA-LUSC
# 79803     copy_number_segment         TCGA  TCGA-UCEC
# 79804     copy_number_segment         TCGA  TCGA-LUSC
# 79805     clinical_supplement         TCGA  TCGA-HNSC
# 79806     copy_number_segment         TCGA  TCGA-CESC
# 79807     copy_number_segment         TCGA   TCGA-LGG
# 79808  biospecimen_supplement         TCGA  TCGA-BRCA
# 79809  biospecimen_supplement         TCGA  TCGA-LIHC
# 79810     copy_number_segment         TCGA  TCGA-SKCM
# 79811     clinical_supplement         TCGA  TCGA-HNSC
# 79812  methylation_beta_value         TCGA  TCGA-LIHC
# 79813     copy_number_segment         TCGA  TCGA-PRAD
# 79814     clinical_supplement         TCGA  TCGA-KIRP
# 79815     copy_number_segment         TCGA   TCGA-LGG
# 79816     copy_number_segment         TCGA  TCGA-KIRC
# 79817     copy_number_segment         TCGA  TCGA-KIRP
# 79818     clinical_supplement         TCGA  TCGA-SARC
# 79819     copy_number_segment         TCGA   TCGA-GBM
# 79820     copy_number_segment         TCGA  TCGA-THCA
# 79821  biospecimen_supplement         TCGA  TCGA-CESC
# 79822     copy_number_segment         TCGA  TCGA-UCEC
# 79823     copy_number_segment         TCGA    TCGA-OV
# 79824  biospecimen_supplement         TCGA  TCGA-STAD
#
#                                       case_id  n_cases
# 0      [02ec7a3a-2812-4a65-93cd-07bf655cc91b]      1.0
# 1      [a09b20b5-c187-4632-b996-0d5314a9885c]      1.0
# 2      [a5af1391-89d3-4f41-930e-7e8272afec98]      1.0
# 3      [ee01b7b0-db62-48bf-804f-617735d234e1]      1.0
# 4      [b2b57e93-2722-4546-9a0b-20155b86edef]      1.0
# 5      [bb8e6886-edc7-4127-a85b-c4f3769b6681]      1.0
# 6      [1f54d21e-752f-496d-8453-4b9b8738cbce]      1.0
# 7      [1e3bc429-50eb-4087-b39a-6d92f03412f7]      1.0
# 8      [2c985b30-0f8f-4c8f-a924-cc6aad7ebf0d]      1.0
# 9      [bc6c516b-591e-4950-b6b0-decafa666f4e]      1.0
# 10     [7b9479ff-23d6-4689-91f0-02efc94300f9]      1.0
# 11     [cfdd2155-57a9-499c-92e1-fb82b577b050]      1.0
# 12     [075d17f2-dd1a-4c12-9e6c-ded1b052d107]      1.0
# 13     [9d7305be-60a3-4ecf-856a-bd5321166590]      1.0
# 14     [a53e9117-0a49-40d8-af40-7867370b671a]      1.0
# 15     [ca242b4c-b879-4e13-a1e7-84c984067189]      1.0
# 16     [ce73d0aa-bb3d-4aa3-8ed3-e9912cf25d38]      1.0
# 17     [8db69f1d-72e2-40ba-ad8a-cf228499840d]      1.0
# 18     [2ff6aede-7bcd-440b-99ab-7a023faf658e]      1.0
# 19     [e0e35051-fbb4-4389-aedb-87bde84d21ad]      1.0
# 20     [69e6da3c-2a03-48bc-bc2a-019b21820149]      1.0
# 21     [e3956736-adbc-49a2-a4a8-a6ae93b8faf3]      1.0
# 22     [92554413-9ebc-4354-8e1b-9682f3a031d9]      1.0
# 23     [66e2fda4-23de-49c6-bb89-82e9edc56e4b]      1.0
# 24     [72c40fba-f502-489b-ad87-843f52655894]      1.0
# 25     [73b63d07-0c1d-4bf2-bf11-b183e090e200]      1.0
# 26     [3429df57-5aae-41aa-8247-6a2ea935a934]      1.0
# 27     [085df27c-9bc2-425a-9a49-547d692ea028]      1.0
# 28     [ad2fe57c-2f44-4d57-83a9-349c8a25c414]      1.0
# 29     [0df9ec46-d600-4845-9d00-2dc2732c68d1]      1.0
# ...                                       ...      ...
# 79795  [3ef779cf-772e-445e-93c8-e1094ea8b878]      1.0
# 79796  [9b714a42-62e8-4b33-947e-6c4850725afd]      1.0
# 79797  [1d880aea-9efe-4a43-8a6a-6a81801da9e0]      1.0
# 79798  [f95063bc-a640-4980-99a7-84645902daf4]      1.0
# 79799  [bee9d6c8-948f-4b76-97ca-b985064249ef]      1.0
# 79800  [eda29281-e803-4217-8603-d6a388408611]      1.0
# 79801  [b4a0bf74-1381-4c17-b97d-206810d9e59a]      1.0
# 79802  [34d5d8b7-9737-43fa-86fe-7c2885c787cf]      1.0
# 79803  [e3dcde4e-5def-4b89-97b4-047b8288919b]      1.0
# 79804  [aabc43bb-485a-49bc-b48a-d4e4ecd46d33]      1.0
# 79805  [c539274c-e2bf-4b5f-ab56-35eff1569bac]      1.0
# 79806  [ff3808e4-eece-4046-819b-fe1019317f8e]      1.0
# 79807  [c371e2b4-209f-40f3-a30c-51df8270b5de]      1.0
# 79808  [dfefb76a-ec6b-4cd2-9d45-2e1e4befc7ea]      1.0
# 79809  [f82aff25-0725-48d1-aefd-d60800f7d1ab]      1.0
# 79810  [7b617d72-ae16-4829-a1d9-274d1d30617f]      1.0
# 79811  [16779eed-f386-4e8f-8475-04d33b9dd160]      1.0
# 79812  [a25a714e-c142-482b-91c8-4fea763e0254]      1.0
# 79813  [6ef0fc2d-f274-4253-bec5-6dbd55953d76]      1.0
# 79814  [7c1f5540-ba4f-498d-ac15-b395197ec5f3]      1.0
# 79815  [0ce8d92b-54e2-45d4-a551-0faf94a27d46]      1.0
# 79816  [060b2104-a015-400e-86c6-6febfb02bbd3]      1.0
# 79817  [43d92569-fe5d-4eeb-a9cc-f7cd26fb3284]      1.0
# 79818  [31397970-59d8-4ee8-83cf-901cd8ba17b3]      1.0
# 79819  [24ae6f30-eec8-49a7-abde-246b3873679e]      1.0
# 79820  [a2e2fac3-cca5-4e33-aa6c-1d9d3ac3aeec]      1.0
# 79821  [6248f2a3-0da9-419f-ab77-c3f6f4353eb5]      1.0
# 79822  [dbbbddae-d711-40f5-bd10-863735885b1f]      1.0
# 79823  [c9524775-6b50-4793-8858-24b6a6d3e4e6]      1.0
# 79824  [be6531b2-d1f3-44ab-9c02-1ceae51ef2bb]      1.0
#
# [79825 rows x 20 columns]

# %%
def get_extension(text):
    fext1=""
    fname, fext2 = os.path.splitext(text)
    if fext2.lower() == '.gz':
        fname, fext1 = os.path.splitext(fname)
    return (fext1 + fext2).lower()

def is_TCGA(text):
    return 'TCGA' in text.upper()

# %%
rm_files_df['file_extension'] = rm_files_df['filename'].progress_apply(get_extension)
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
rm_files_df.file_extension.unique()
# Out:
# array([], dtype=object)

# %%
rm_files_df.where(rm_files_df['filename'].progress_apply(is_TCGA) != True).dropna(how='all')

# %%
import shutil
import pathlib

def remove_file(rowdata):
    fid = rowdata['file_id']
    path = pathlib.Path('../GDC_Download/%s' % fid)
    print("removing %s" % path)
    if path.exists:
        if path.is_file():
            os.remove(path)
            return
        if path.is_dir():
            shutil.rmtree(path)
            return

# %%
rm_files_df.apply(remove_file, axis='columns')

# %%
def verify_download(content, md5sum):
    md5_hasher = hashlib.md5()
    md5_hasher.update(content)
    return md5_hasher.hexdigest() == md5sum

def ensure_directory_exists(path):
    if type(path) is str:
        path = pathlib.Path(path)
    if path.exists() and path.is_dir():
#         print("dir_at_path_exists_already")
        return
    if path.exists() and not path.is_dir():
#         print("path_was_file")
        os.remove(path)
#         print("file_removed")
    os.makedirs(path, exist_ok=True)
#     print("dir_created")
    return
        
def download_GDC_file(data_row):
    response = requests.get(endpoints['data'] / data_row['file_id'], stream=True)
    total_response_size = int(response.headers.get('content-length', 0))
    if total_response_size != int(data_row['file_size']):
        print("mismatched response size: %d, File size should be: %d" % (total_response_size, int(data_row['file_size'])))
    blocksize = 32*1024
    with io.BytesIO() as f:
        for data in tqdm(response.iter_content(blocksize), total=total_response_size, unit='B', unit_scale=True):
            f.write(data)
        content = f.getvalue()
    parent_path = pathlib.Path('../GDC_Download') / data_row['file_id']
    ensure_directory_exists(parent_path)
    target = parent_path / data_row['file_name']
    with open(target, 'wb') as f:
        print("writing %s" % target)
        f.write(content)
        f.close()
    return verify_download(content, data_row['md5sum'])

# %%
# dl_files_df.progress_apply(download_GDC_file, axis='columns')
dl_files_df.progress_apply(remove_file, axis='columns')
# Out:
# E:\Anaconda3\envs\kaggle\lib\site-packages\tqdm\_tqdm.py:610: RuntimeWarning: divide by zero encountered in long_scalars
#   total = df.size // len(df)
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Empty DataFrame
# Columns: [access, data_category, data_format, data_type, error_type, experimental_strategy, file_id, file_name, file_size, file_state, md5sum, platform, state, state_comment, submitter_id, type, program_name, project_id, case_id, n_cases]
# Index: []

# %%
from datetime import datetime
def generate_manifest_file(df):
    payload = {'ids': df['file_id'].tolist()}
    response = requests.post(endpoints['manifest'], data=payload)
    manifest_path = pathlib.Path('../manifest') / ("gdc_manifest_%s.txt" % datetime.today().strftime("%Y_%m_%d_%H_%M"))
    with open(manifest_path, 'wb') as file:
        file.write(response.content)
        file.close()
    return

# %%
generate_manifest_file(wanted_files)

# %%
import gc
gc.collect()

# %%
new_manifest = pd.read_csv(pathlib.Path('../manifest')/"gdc_manifest_2018_02_22_17_43.txt", sep="\t")

# %%
new_manifest

# %%
def clean_path_for_download(row_data):
    root_path = pathlib.Path("../GDC_Download")
    target_dir = root_path / row_data['id']
    target_file = target_dir / row_data['filename']
    parcel_file = target_dir / "logs" / (row_data['filename'] + ".parcel")
    if target_dir.exists():
        if not target_dir.is_dir():
            os.remove(target_dir)
            return False
        else:
            if target_file.is_file() and parcel_file.is_file():
                return True
            else:
                shutil.rmtree(target_dir)
                return False
    else:
        return False

# %%
new_manifest.progress_apply(clean_path_for_download, axis='columns')
